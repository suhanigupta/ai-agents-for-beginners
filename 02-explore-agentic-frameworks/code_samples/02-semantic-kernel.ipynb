# %% [markdown]
# # Semantic Kernel
#
# In this code sample, you will use the [Semantic Kernel](https://aka.ms/ai-agents-beginners/semantic-kernel) AI Framework to create a basic agent.
#
# The goal of this sample is to show you the steps that we will later use in the additional code samples when implementing the different agentic patterns.

# %% [markdown]
# ## Import the Needed Python Packages

# %%
# %pip install semantic-kernel

import json
import os 

from typing import Annotated

from dotenv import load_dotenv

from IPython.display import display, HTML

from openai import AsyncOpenAI

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent, StreamingTextContent
from semantic_kernel.functions import kernel_function
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: semantic-kernel in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (1.31.0)
# Requirement already satisfied: aiohttp~=3.8 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (3.11.18)
# Requirement already satisfied: cloudevents~=1.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.11.1)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (2.11.5)
# Requirement already satisfied: pydantic-settings~=2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (2.9.1)
# Requirement already satisfied: defusedxml~=0.7 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: azure-identity>=1.13 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.23.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (2.2.6)
# Requirement already satisfied: openai>=1.67 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.82.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.12.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.33.1)
# Requirement already satisfied: prance<25.4.9,>=23.6.21 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (25.4.8.0)
# Requirement already satisfied: pybars4~=0.9 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (1.15.3)
# Requirement already satisfied: protobuf in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (5.29.4)
# Requirement already satisfied: typing-extensions>=4.13 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from semantic-kernel) (4.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiohttp~=3.8->semantic-kernel) (1.20.0)
# Requirement already satisfied: deprecation<3.0,>=2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: packaging in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from deprecation<3.0,>=2.0->cloudevents~=1.0->semantic-kernel) (25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jinja2~=3.1->semantic-kernel) (3.0.2)
# Requirement already satisfied: isodate in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.7.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.1)
# Requirement already satisfied: parse in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug<3.1.2 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.25.1)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.32.3)
# Requirement already satisfied: rfc3339-validator in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.11.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.21.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.54b1)
# Requirement already satisfied: chardet>=5.2 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.18.10 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (0.18.10)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from pydantic-settings~=2.0->semantic-kernel) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2025.4.26)
# Requirement already satisfied: aioice<1.0.0,>=0.10.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.10.1)
# Requirement already satisfied: av<15.0.0,>=14.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (14.4.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.17.1)
# Requirement already satisfied: cryptography>=44.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (45.0.2)
# Requirement already satisfied: google-crc32c>=1.1 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.12.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aiortc>=1.9.0->semantic-kernel) (25.1.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from azure-identity>=1.13->semantic-kernel) (1.34.0)
# Requirement already satisfied: msal>=1.30.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from azure-identity>=1.13->semantic-kernel) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from azure-core>=1.31.0->azure-identity>=1.13->semantic-kernel) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel) (1.17.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openai>=1.67->semantic-kernel) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openai>=1.67->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openai>=1.67->semantic-kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openai>=1.67->semantic-kernel) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openai>=1.67->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from openai>=1.67->semantic-kernel) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (0.16.0)
# Requirement already satisfied: colorama in c:\users\suhani gupta\appdata\roaming\python\python313\site-packages (from tqdm>4->openai>=1.67->semantic-kernel) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Creating the Client
#
# In this sample, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) for access to the LLM.
#
# The `ai_model_id` is defined as `gpt-4o-mini`. Try changing the model to another model available on the GitHub Models marketplace to see the different results.
#
# For us to use the `Azure Inference SDK` that is used for the `base_url` for GitHub Models, we will use the `OpenAIChatCompletion` connector within Semantic Kernel. There are also other [available connectors](https://learn.microsoft.com/semantic-kernel/concepts/ai-services/chat-completion) to use Semantic Kernel for other model providers.

# %%
import random   

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
load_dotenv()
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"), 
    base_url="https://models.inference.ai.azure.com/",
)

# Create an AI Service that will be used by the `ChatCompletionAgent`
chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %% [markdown]
# ## Creating the Agent
#
# Below we create the Agent called `TravelAgent`.
#
# For this example, we are using very simple instructions. You can change these instructions to see how the agent responds differently.

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service, 
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## Running the Agents
#
# Now we can run the Agent by defining the `ChatHistory` and adding the `system_message` to it. We will use the `AGENT_INSTRUCTIONS` that we defined earlier.
#
# After these are defined, we create a `user_inputs` that will be what the user is sending to the agent. In this case, we have set this message to `Plan me a sunny vacation`.
#
# Feel free to change this message to see how the agent responds differently.

# %%
user_inputs = [
    "Plan me a day trip.",
    "I don't like that destination. Plan me another vacation.",
]

async def main():
    thread: ChatHistoryAgentThread | None = None

    for user_input in user_inputs:
        html_output = (
            f"<div style='margin-bottom:10px'>"
            f"<div style='font-weight:bold'>User:</div>"
            f"<div style='margin-left:20px'>{user_input}</div></div>"
        )

        agent_name = None
        full_response: list[str] = []
        function_calls: list[str] = []

        # Buffer to reconstruct streaming function call
        current_function_name = None
        argument_buffer = ""

        async for response in agent.invoke_stream(
            messages=user_input,
            thread=thread,
        ):
            thread = response.thread
            agent_name = response.name
            content_items = list(response.items)

            for item in content_items:
                if isinstance(item, FunctionCallContent):
                    if item.function_name:
                        current_function_name = item.function_name

                    # Accumulate arguments (streamed in chunks)
                    if isinstance(item.arguments, str):
                        argument_buffer += item.arguments
                elif isinstance(item, FunctionResultContent):
                    # Finalize any pending function call before showing result
                    if current_function_name:
                        formatted_args = argument_buffer.strip()
                        try:
                            parsed_args = json.loads(formatted_args)
                            formatted_args = json.dumps(parsed_args)
                        except Exception:
                            pass  # leave as raw string

                        function_calls.append(f"Calling function: {current_function_name}({formatted_args})")
                        current_function_name = None
                        argument_buffer = ""

                    function_calls.append(f"\nFunction Result:\n\n{item.result}")
                elif isinstance(item, StreamingTextContent) and item.text:
                    full_response.append(item.text)

        if function_calls:
            html_output += (
                "<div style='margin-bottom:10px'>"
                "<details>"
                "<summary style='cursor:pointer; font-weight:bold; color:#0066cc;'>Function Calls (click to expand)</summary>"
                "<div style='margin:10px; padding:10px; background-color:#f8f8f8; "
                "border:1px solid #ddd; border-radius:4px; white-space:pre-wrap; font-size:14px; color:#333;'>"
                f"{chr(10).join(function_calls)}"
                "</div></details></div>"
            )

        html_output += (
            "<div style='margin-bottom:20px'>"
            f"<div style='font-weight:bold'>{agent_name or 'Assistant'}:</div>"
            f"<div style='margin-left:20px; white-space:pre-wrap'>{''.join(full_response)}</div></div><hr>"
        )

        display(HTML(html_output))

await main()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Plan me a day trip.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>Your day trip is planned for New York City, USA! Here’s an itinerary to make the most of your time:
#
# ### Morning:
# 1. **Breakfast at a Local Café**: Start your day with a classic New York breakfast. Try a bagel with cream cheese and lox at a local favorite like Russ & Daughters Café.
#
# 2. **Visit Central Park**: Take a stroll through Central Park. You can explore iconic spots like Bethesda Terrace, Bow Bridge, and the Central Park Zoo.
#
# ### Midday:
# 3. **Explore the Museums**:
#    - **The Metropolitan Museum of Art**: Admire world-class art collections. The museum is huge, so pick a few sections that interest you most.
#    - **American Museum of Natural History**: If you're more into science, this museum is fascinating. Don't miss the dinosaur fossils!
#
# 4. **Lunch in the Upper West Side**: Grab a casual lunch at a bistro or deli, such as Jacob’s Pickles for Southern comfort food or a classic deli sandwich at Barney Greengrass.
#
# ### Afternoon:
# 5. **Visit Times Square**: After lunch, head to Times Square and soak in the bright lights and vibrant atmosphere. Check out some shops or take photos with the iconic billboards.
#
# 6. **Take a Walk or a Subway Ride Down to Lower Manhattan**: See Wall Street, and if time allows, visit the 9/11 Memorial & Museum.
#
# ### Evening:
# 7. **Dinner in SoHo**: Head to SoHo for dinner. Consider trying out popular spots like Carbone for Italian or Lure Fishbar for seafood.
#
# 8. **Evening Activity**: End your day with a Broadway show or visit a rooftop bar with stunning views of the city skyline.
#
# ### Tips:
# - Wear comfortable shoes as you'll be walking a lot.
# - Use public transportation for easier travel between locations.
# - Check for any available tickets in advance, especially for shows and museums.
#
# Enjoy your day in New York City!</div></div><hr>
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>I don't like that destination. Plan me another vacation.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>Your new vacation destination is Paris, France! Here’s a suggested itinerary for a fabulous day trip:
#
# ### Morning:
# 1. **Breakfast at a Parisian Café**: Start your day with a classic French breakfast. Enjoy a croissant or pain au chocolat with a café au lait at a local café like Café de Flore or Les Deux Magots.
#
# 2. **Visit the Eiffel Tower**: Head to the Eiffel Tower early to avoid long queues. Ascend to the top for breathtaking views of the city.
#
# ### Midday:
# 3. **Stroll Through the Champ de Mars**: After visiting the Eiffel Tower, take a leisurely walk through the Champ de Mars park, where you can enjoy the beautiful gardens and views of the tower.
#
# 4. **Lunch in Le Marais**: Travel to Le Marais for lunch. Try a savory crepe at Breizh Café or indulge in some falafel at L'As du Fallafel.
#
# ### Afternoon:
# 5. **Explore the Louvre Museum**: Spend your afternoon at the Louvre. Focus on must-see pieces like the Mona Lisa and the Venus de Milo. Consider booking skip-the-line tickets.
#
# 6. **Walk Along the Seine**: After the museum, take a relaxing walk along the Seine River, stopping at iconic bridges like Pont des Arts and Pont Alexandre III.
#
# ### Evening:
# 7. **Dinner in Montmartre**: Head to Montmartre for dinner. Choose a quaint bistro like Le Consulat or La Mère Catherine, and enjoy traditional French cuisine.
#
# 8. **Visit the Sacré-Cœur Basilica**: After dinner, walk up to the Sacré-Cœur Basilica for panoramic views of Paris, especially stunning at sunset.
#
# ### Tips:
# - Be sure to wear comfortable shoes for walking.
# - Use the Paris Metro for easy transport between locations.
# - Consider purchasing a Paris Pass for discounts on attractions and transportation.
#
# Enjoy your romantic getaway in Paris!</div></div><hr>
